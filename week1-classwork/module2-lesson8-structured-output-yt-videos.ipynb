# %%
# !uv add youtube-transcript-api
# Out:
# Resolved 150 packages in 4ms
# Audited 131 packages in 0.12ms

# %%
#Get the Transcript
from youtube_transcript_api import YouTubeTranscriptApi

video_id = 'ph1PxZIkz1o'

ytt_api = YouTubeTranscriptApi()
transcript = ytt_api.fetch(video_id)

# %%
transcript
# Out:
# FetchedTranscript(snippets=[FetchedTranscriptSnippet(text='So hi everyone. Uh today we are going to', start=0.0, duration=5.04), FetchedTranscriptSnippet(text='talk about our upcoming course. The', start=2.96, duration=3.52), FetchedTranscriptSnippet(text='upcoming course is called machine', start=5.04, duration=5.92), FetchedTranscriptSnippet(text='learning zoom camp. And um this is', start=6.48, duration=5.92), FetchedTranscriptSnippet(text='already I put the link in the', start=10.96, duration=3.599), FetchedTranscriptSnippet(text="description. So if you're watching um", start=12.4, duration=4.719), FetchedTranscriptSnippet(text="this video in recording or you're", start=14.559, duration=4.88), FetchedTranscriptSnippet(text='watching it live, you go here in the', start=17.119, duration=4.561), FetchedTranscriptSnippet(text='description after under this video and', start=19.439, duration=5.6), FetchedTranscriptSnippet(text='then you see a link course. uh click on', start=21.68, duration=6.24), FetchedTranscriptSnippet(text='that link and this bring you will bring', start=25.039, duration=4.64), FetchedTranscriptSnippet(text='you to', start=27.92, duration=6.159), FetchedTranscriptSnippet(text='this website this GitHub page.', start=29.679, duration=7.121), FetchedTranscriptSnippet(text='This GitHub page is the main entry point', start=34.079, duration=7.201), FetchedTranscriptSnippet(text="to our course and um yeah I think it's", start=36.8, duration=6.4), FetchedTranscriptSnippet(text='more or less self-explanatory. If you', start=41.28, duration=3.92), FetchedTranscriptSnippet(text='want to sign up this is the button you', start=43.2, duration=5.44), FetchedTranscriptSnippet(text='click and the actual course starts in on', start=45.2, duration=5.839), FetchedTranscriptSnippet(text="September 15th. it means that it's uh", start=48.64, duration=5.04), FetchedTranscriptSnippet(text='slightly less than one one month before', start=51.039, duration=4.721), FetchedTranscriptSnippet(text='the course starts and the purpose of', start=53.68, duration=5.28), FetchedTranscriptSnippet(text="today's um session is to just answer", start=55.76, duration=5.119), FetchedTranscriptSnippet(text='your questions. So you have some', start=58.96, duration=4.16), FetchedTranscriptSnippet(text='questions and uh you can ask these', start=60.879, duration=5.121), FetchedTranscriptSnippet(text='questions using uh you can ask your', start=63.12, duration=4.48), FetchedTranscriptSnippet(text='questions using the pinned link. So', start=66.0, duration=3.76), FetchedTranscriptSnippet(text="there's a pinned link in the live chat.", start=67.6, duration=6.64), FetchedTranscriptSnippet(text='Click on that link um and there ask your', start=69.76, duration=7.359), FetchedTranscriptSnippet(text='questions. So yeah, this is how it looks', start=74.24, duration=6.96), FetchedTranscriptSnippet(text='like and I am just going to uh use this', start=77.119, duration=7.281), FetchedTranscriptSnippet(text='thing. So we can also go to SLO and use', start=81.2, duration=5.919), FetchedTranscriptSnippet(text="ML Zoom camp and I'm going to use that", start=84.4, duration=5.039), FetchedTranscriptSnippet(text='for answering questions. Uh one thing', start=87.119, duration=3.841), FetchedTranscriptSnippet(text='though, so before we start, I just', start=89.439, duration=3.601), FetchedTranscriptSnippet(text='wanted to mention that um this course', start=90.96, duration=5.36), FetchedTranscriptSnippet(text='has been running for uh this will be the', start=93.04, duration=6.0), FetchedTranscriptSnippet(text="fifth edition of this course. So we've", start=96.32, duration=4.159), FetchedTranscriptSnippet(text='been doing this course for quite some', start=99.04, duration=4.0), FetchedTranscriptSnippet(text='time. Many people already graduated from', start=100.479, duration=5.521), FetchedTranscriptSnippet(text='this course and um most of the content', start=103.04, duration=6. ...

# %%
def format_timestamp(seconds: float) -> str:
    """Convert seconds to H:MM:SS if > 1 hour, else M:SS"""
    total_seconds = int(seconds)
    hours, remainder = divmod(total_seconds, 3600)
    minutes, secs = divmod(remainder, 60)

    if hours > 0:
        return f"{hours}:{minutes:02}:{secs:02}"
    else:
        return f"{minutes}:{secs:02}"

def make_subtitles(transcript) -> str:
    lines = []

    for entry in transcript:
        ts = format_timestamp(entry.start)
        text = entry.text.replace('\n', ' ')
        lines.append(ts + ' ' + text)

    return '\n'.join(lines)

subtitles = make_subtitles(transcript)

# %%
make_subtitles(transcript)
# Out:
# "0:00 So hi everyone. Uh today we are going to\n0:02 talk about our upcoming course. The\n0:05 upcoming course is called machine\n0:06 learning zoom camp. And um this is\n0:10 already I put the link in the\n0:12 description. So if you're watching um\n0:14 this video in recording or you're\n0:17 watching it live, you go here in the\n0:19 description after under this video and\n0:21 then you see a link course. uh click on\n0:25 that link and this bring you will bring\n0:27 you to\n0:29 this website this GitHub page.\n0:34 This GitHub page is the main entry point\n0:36 to our course and um yeah I think it's\n0:41 more or less self-explanatory. If you\n0:43 want to sign up this is the button you\n0:45 click and the actual course starts in on\n0:48 September 15th. it means that it's uh\n0:51 slightly less than one one month before\n0:53 the course starts and the purpose of\n0:55 today's um session is to just answer\n0:58 your questions. So you have some\n1:00 questions and uh you can ask these\n1:03 questions using uh you can ask your\n1:06 questions using the pinned link. So\n1:07 there's a pinned link in the live chat.\n1:09 Click on that link um and there ask your\n1:14 questions. So yeah, this is how it looks\n1:17 like and I am just going to uh use this\n1:21 thing. So we can also go to SLO and use\n1:24 ML Zoom camp and I'm going to use that\n1:27 for answering questions. Uh one thing\n1:29 though, so before we start, I just\n1:30 wanted to mention that um this course\n1:33 has been running for uh this will be the\n1:36 fifth edition of this course. So we've\n1:39 been doing this course for quite some\n1:40 time. Many people already graduated from\n1:43 this course and um most of the content\n1:46 we use here is the content I uh recorded\n1:49 like four years ago\n1:52 but we are updating the content so cuz u\n1:54 back then everyone was using Python 3.8\n1:58 eight or nine something like. So yeah,\n2:01 we are re-recording some of the things\n2:03 in particular. Module one, two, three,\n2:06 four will uh stay the same cuz uh this\n2:10 uh these are the fundamentals. They\n2:11 didn't change. But module five we uh\n2:15 will update. Module 6 will stay the\n2:17 same. Module 8 we will update. Module 9\n2:21 update update. And this we will not\n2:23 include like we only include it once and\n2:25 this thing get outdated very fast. So we\n2:28 just I just didn't bother updating this\n2:30 at all and it's pretty advanced\n2:32 material. So we will update like four\n2:34 out of 10 modules. So that's the plan.\n2:38 Uh and we already had some workshops for\n2:41 this. Anyways um you have some questions\n2:44 and these questions you use slido for\n2:47 asking these questions and let's get\n2:49 started.\n2:50 Um Alexi question is there a chance of\n2:53 job placement after the program? How\n2:55 deep are we going into computer vision\n2:56 and rock? Okay, so there are three\n2:58 questions actually here. Uh chance of\n3:01 job placement. So we do not provide you\n3:03 job placement. So we are not recruiters.\n3:06 We just teach this uh and we are not a\n3:09 boot camp where you pay money. Right? So\n3:11 this is a free boot camp and our\n3:13 resources are limited. So we cannot\n3:14 really uh do this for you. That said,\n3:18 many of many course participants who\n3:21 took this course in the past\n3:23 successfully found the job. So this is\n3:25 this is going to be the fifth time we\n3:28 are hosting this. So yeah, many many\n3:31 people have graduated from this course\n3:33 and many people found the jobs. So yes,\n3:35 there is a high chance to find a job\n3:38 placement after the program because the\n3:41 teach we the skills we teach here the\n3:43 skills we cover here\n3:45 they are the most important skills for a\n3:48 machine learning engineer. So first we\n3:49 focus on the machine learning part where\n3:52 we cover scikitlearn\n3:54 um like simplest model models and then\n3:57 we go deeper on the deployment side. So\n4:00 th ...

# %%
instructions = """
Summarize the transcript and describe the main purpose of the video
and the main ideas.

Also output chapters with time. Use usual sentence case, not Title Case for the chapter.

Output format:

<OUTPUT>
Summary

timestamp chapter
timestamp chapter
...
timestamp chapter
</OUTPUT>

don't include <OUTPUT> in the output
"""

# %%
#Interact with LLM
from openai import OpenAI

openai_client = OpenAI()

def interact_with_llm(user_prompt, instructions=None, model="gpt-4o-mini"):
    messages = []

    if instructions:
        messages.append({
            "role": "system",
            "content": instructions
        })

    messages.append({
        "role": "user",
        "content": user_prompt
    })

    response = openai_client.responses.create(
        model=model,
        input=messages
    )

    return response.output_text

# %%
llm_response = interact_with_llm(make_subtitles(transcript), instructions=instructions)

# %%
print(llm_response)
# Out:
# The video discusses an upcoming course titled "Machine Learning Zoom Camp," set to launch on September 15th. The presenter discusses course content, structure, and prerequisites while addressing common questions from potential participants. The course emphasizes practical machine learning engineering skills, focusing on deployment and engineering aspects while covering foundational topics. The Q&A section includes queries about job placement, prerequisites, recommended resources, and how to maximize learning.
#
# **Key Ideas:**
# - Overview of the "Machine Learning Zoom Camp" course and enrollment details.
# - Focus on practical skills critical for machine learning engineering, especially in deployment.
# - Clarification on prerequisites such as programming comfort, and some basic knowledge in linear algebra.
# - Discussion around job prospects post-course, emphasizing that the course aims to equip participants with skills that enhance employability.
# - Responses to questions about course content, updates, and the nature of assessments, including the structure of projects and certificates.
#
# **Chapters:**
# 0:00 Introduction to the course
# 0:48 Course details and enrollment
# 2:38 Course content and updates
# 4:00 Job placement discussion
# 5:30 Computer vision and deep learning content
# 6:08 Prerequisites for the course
# 8:29 Command line usage in the course
# 9:32 Environment setup and requirements
# 10:54 Course target audience
# 12:00 Recommended companion book
# 13:45 Math prerequisites for the course
# 15:45 Equipment requirements
# 17:10 Using AI tools for learning
# 19:20 Course relevance to different job roles
# 22:25 Description of cross-course content
# 24:00 Updates and new materials planned
# 25:48 Project descriptions and importance
# 28:54 Learning timeline and deadlines
# 30:20 Live interaction and session details
# 32:00 Workload and time commitment
# 34:25 Course project alignment with job readiness
# 37:45 Certificate issuance criteria
# 39:00 Learning outcomes and next steps
# 41:50 Final remarks and course signing off

# %%
#Pydantic takes a Output Text and and matches it to a Object Defined
from pydantic import BaseModel

class Chapter(BaseModel):
    timestamp: str
    title: str

class YTSummaryResponse(BaseModel):
    summary: str
    chapters: list[Chapter]

# %%
# Here output_format is the Pydantic Model


def llm_structured(instructions, user_prompt, output_format, model="gpt-4o-mini"):
    messages = [
        {"role": "system", "content": instructions},
        {"role": "user", "content": user_prompt}
    ]

    response = openai_client.responses.parse( # note the use of responses.parse instead of responses.create
        model=model,
        input=messages,
        text_format=output_format
    )

    return response.output_parsed

# %%
structured_response = llm_structured(instructions=instructions,user_prompt=make_subtitles(transcript),output_format=YTSummaryResponse)

# %%
structured_response
# Out:
# YTSummaryResponse(summary='The video discusses the upcoming "Machine Learning Zoom Camp" course starting on September 15, addressing various topics related to the course structure, prerequisites, content updates, and overall goals. The presenter emphasizes that this is an engineering-focused course rather than a data science course, where participants will learn practical skills in machine learning and deployment. Several questions from the audience about job placements, prerequisites, module contents, and expected outcomes are answered, indicating that while formal placement support is not provided, many past participants found jobs after completing the course. The course aims to equip learners with enough skills for entry-level ML engineering roles, and encourages self-driven learning and project completion for certification.', chapters=[Chapter(timestamp='0:00', title='Introduction to the upcoming course'), Chapter(timestamp='1:00', title='Course details and GitHub page overview'), Chapter(timestamp='2:00', title='Course content updates and structure'), Chapter(timestamp='3:00', title='Job placement and outcomes post-course'), Chapter(timestamp='4:00', title='Computer vision coverage in the course'), Chapter(timestamp='6:00', title='Prerequisites for course participants'), Chapter(timestamp='8:00', title='Command line use in the course'), Chapter(timestamp='10:00', title='Using GitHub Codespaces for the course'), Chapter(timestamp='11:00', title='Prior knowledge for deep learning'), Chapter(timestamp='12:00', title='Target audience for ML engineers vs data scientists'), Chapter(timestamp='13:00', title='Recommended reading and available resources'), Chapter(timestamp='14:00', title='Mathematics requirements for the course'), Chapter(timestamp='15:00', title='Technical requirements and necessary tools'), Chapter(timestamp='18:00', title='ChatGPT as a learning aid'), Chapter(timestamp='20:00', title='Course suitability for MLOps and other engineering roles'), Chapter(timestamp='22:00', title='Overview of available Zoom Camp courses'), Chapter(timestamp='24:00', title='New materials and updates this course'), Chapter(timestamp='28:00', title='Course deadlines and interactive sessions'), Chapter(timestamp='30:00', title='Courseware and community interaction'), Chapter(timestamp='31:00', title='Projects and their impact on job readiness'), Chapter(timestamp='33:00', title='Final project expectations and portfolio building'), Chapter(timestamp='36:00', title='Online and offline resources for Python skills'), Chapter(timestamp='38:00', title='How homework and peer reviews work'), Chapter(timestamp='40:00', title='Certificates and job readiness'), Chapter(timestamp='44:00', title='Closing remarks and Q&A access details')])

# %%
structured_response.summary
# Out:
# 'The video discusses the upcoming "Machine Learning Zoom Camp" course starting on September 15, addressing various topics related to the course structure, prerequisites, content updates, and overall goals. The presenter emphasizes that this is an engineering-focused course rather than a data science course, where participants will learn practical skills in machine learning and deployment. Several questions from the audience about job placements, prerequisites, module contents, and expected outcomes are answered, indicating that while formal placement support is not provided, many past participants found jobs after completing the course. The course aims to equip learners with enough skills for entry-level ML engineering roles, and encourages self-driven learning and project completion for certification.'

# %%
structured_response.chapters
# Out:
# [Chapter(timestamp='0:00', title='Introduction to the upcoming course'),
#  Chapter(timestamp='1:00', title='Course details and GitHub page overview'),
#  Chapter(timestamp='2:00', title='Course content updates and structure'),
#  Chapter(timestamp='3:00', title='Job placement and outcomes post-course'),
#  Chapter(timestamp='4:00', title='Computer vision coverage in the course'),
#  Chapter(timestamp='6:00', title='Prerequisites for course participants'),
#  Chapter(timestamp='8:00', title='Command line use in the course'),
#  Chapter(timestamp='10:00', title='Using GitHub Codespaces for the course'),
#  Chapter(timestamp='11:00', title='Prior knowledge for deep learning'),
#  Chapter(timestamp='12:00', title='Target audience for ML engineers vs data scientists'),
#  Chapter(timestamp='13:00', title='Recommended reading and available resources'),
#  Chapter(timestamp='14:00', title='Mathematics requirements for the course'),
#  Chapter(timestamp='15:00', title='Technical requirements and necessary tools'),
#  Chapter(timestamp='18:00', title='ChatGPT as a learning aid'),
#  Chapter(timestamp='20:00', title='Course suitability for MLOps and other engineering roles'),
#  Chapter(timestamp='22:00', title='Overview of available Zoom Camp courses'),
#  Chapter(timestamp='24:00', title='New materials and updates this course'),
#  Chapter(timestamp='28:00', title='Course deadlines and interactive sessions'),
#  Chapter(timestamp='30:00', title='Courseware and community interaction'),
#  Chapter(timestamp='31:00', title='Projects and their impact on job readiness'),
#  Chapter(timestamp='33:00', title='Final project expectations and portfolio building'),
#  Chapter(timestamp='36:00', title='Online and offline resources for Python skills'),
#  Chapter(timestamp='38:00', title='How homework and peer reviews work'),
#  Chapter(timestamp='40:00', title='Certificates and job readiness'),
#  Chapter(timestamp='44:00', title='Closing remarks and Q&A access details')]
